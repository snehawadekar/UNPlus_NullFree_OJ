# %%
import matplotlib.pyplot as plt

# %%
 
# print dataframe.
# df

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(5)
y1 = [0.7909164428710938,  0.8257734775543213 ,0.8809921741485596 , 0.8189539909362793, 0.847132682800293] # correlated sampling
y2 = [(1.4464843273162842 + 0.7909164428710938),  (4.807533025741577 + 0.8257734775543213), (4.089139461517334 + 0.8809921741485596),(6.429215431213379+0.8189539909362793), (2.960028648376465 + 0.847132682800293)] #cop[y based samp]

y3 = [12.611318111419678,  9.540351629257202 ,30.049304723739624 , 22.069141149520874, 13.986800909042358] #only copy based sampling
width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='red')
plt.bar(x, y2, width,bottom=y1, color='green')
plt.bar(x+0.2, y3, width, color='cyan')
plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q5', 'Q17'])
plt.xlabel("Queries(1 gb databazse)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["Correlated S(CS)", "Copy-Based M. after CS", "Only Copy Based M."],  loc="upper left")
plt.show()

# %%
x = np.arange(5)
y1 = [0.7909164428710938,  0.8257734775543213 ,0.8809921741485596 , 0.8189539909362793, 0.847132682800293] # correlated sampling
y2 = [(1.4464843273162842 + 0.7909164428710938),  (4.807533025741577 + 0.8257734775543213), (4.089139461517334 + 0.8809921741485596),(6.429215431213379+0.8189539909362793), (2.960028648376465 + 0.847132682800293)] #cop[y based samp]

y3 = [12.611318111419678,  9.540351629257202 ,30.049304723739624 , 22.069141149520874, 13.986800909042358] #only copy based sampling
width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='red')
plt.bar(x, y2, width,bottom=y1, color='green')
plt.bar(x+0.2, y3, width, color='cyan')
plt.xticks(x, ['Q1', 'Q2', 'Q3', 'Q5', 'Q17'])
plt.xlabel("Queries (10 GB)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["Correlated S(CS)", "Copy-Based M. after CS", "Only Copy Based M."],  loc="upper left")
plt.show()

# %% [markdown]
# csnew + only view

# %%
x = np.arange(5)
#csnew + view
y1 = [5.867359399795532 , 
      4.448164224624634 ,
      1.3264274597167969 ,
      21.435041666030884,
      2.2896459102630615

      ] 
y2 = [5.867359399795532 + 3.9681241512298584  , 
      4.448164224624634 + 40.687594175338745 ,
      1.3264274597167969 +  3.8866984844207764,
      21.435041666030884 + 17.223840475082397  ,
      2.2896459102630615 + 5.282226324081421


      ] 

# only view
y3 = [33.18908977508545,
      234.5566992759705 ,
      8.368826866149902 ,
     142.8275055885315,
     24.421877145767212
      ] 

# remaining pipeline extraction time

width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='orange')
plt.bar(x, y2, width,bottom=y1, color='green')
plt.bar(x+0.2, y3, width, color='cyan')
# plt.bar(x+0.2, y4, width,bottom=y3, color='green')
plt.xticks(x, ['Q1', 'Q2','Q4', 'Q10', 'Q16'])
plt.xlabel("Queries (10 GB db)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["CS2_new", "CS2_new + view", "Only view"],  loc="upper left")
plt.show()

# %% [markdown]
# view ctid vs copy recursive halving minimization:

# %%
x = np.arange(4)
#view sampling
y1 = [33.18908977508545, 
      7.368826866149902 ,
      142.8275055885315 ,
      14.421877145767212,
      ] 
y2 = [(122.78184585571289 - 35.1  -21.3 ),
       (28.850800800323487 - 8 -1.8),
       (198.94315757751465 -  145.7 - 16.9 ),
      (26.218768262863158 - 14.9 - 1.4)] #cop[y based samp]


#copy based rec halving sampling
y3 = [480.01910519599915,
      56.426374673843384 ,
      491.75361132621765 ,
      21.30469012260437,
      ] 

# remaining pipeline extraction time
y4 = [ 
      (546.7312349319458 - 483.1  - 18.9 ),
      (66.4949673652649 - 58.4 - 1.9),
      (629.1616370201111-  579.3 - 17.2),
      (121.42245593070984 - 80 - 1.4), 
      ] 
width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x, y1, width, color='orange')
plt.bar(x, y2, width,bottom=y1, color='green')
plt.bar(x+0.2, y3, width, color='cyan')
plt.bar(x+0.2, y4, width,bottom=y3, color='green')
plt.xticks(x, ['Q1', 'Q4', 'Q10', 'Q16'])
plt.xlabel("Queries (10 GB db)")
plt.ylabel("Run Time(Seconds)")
plt.legend(["View", "Copy-Based", "remaining pipeline."],  loc="upper left")
plt.show()
